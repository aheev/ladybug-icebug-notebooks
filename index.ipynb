# %% [markdown]
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Nunito:wght@600;700;800&family=Overpass:wght@400;500;600;700&display=swap');
# .jp-Notebook, .jp-NotebookPanel-notebook, body { background: #17181c !important; }
# .ladybug-index {
#   --white: #ffffff;
#   --text: #c1c3c8;
#   --muted: #888c96;
#   --panel: #23262f;
#   --border: #353841;
#   --bg: #17181c;
#   --accent: #dc6428;
#   --accent-high: #e0743e;
#   --shadow: 0 8px 4px rgba(0,0,0,.08), 0 5px 2px rgba(0,0,0,.08), 0 3px 2px rgba(0,0,0,.12), 0 1px 1px rgba(0,0,0,.15);
#   box-sizing: border-box;
#   min-height: 100vh;
#   margin: -14px -14px 0;
#   padding: 2.5rem clamp(1.25rem, 4vw, 4rem) 4rem;
#   color: var(--text);
#   background: var(--bg);
#   font-family: Overpass, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;
#   line-height: 1.8;
# }
# .ladybug-index * { box-sizing: border-box; }
# .ladybug-index .wrap { max-width: 72rem; margin: 0 auto; }
# .ladybug-index .brand {
#   display: inline-flex;
#   align-items: center;
#   gap: .65rem;
#   color: var(--accent-high);
#   font-weight: 700;
#   letter-spacing: 0;
#   margin-bottom: 2rem;
# }
# .ladybug-index .mark {
#   width: 1.9rem;
#   height: 1.9rem;
#   border-radius: .45rem;
#   display: grid;
#   place-items: center;
#   color: #17181c;
#   background: var(--accent-high);
#   font-family: Nunito, Overpass, sans-serif;
#   font-weight: 800;
# }
# .ladybug-index h1 {
#   margin: 0;
#   max-width: 48rem;
#   color: var(--white);
#   font-family: Nunito, Overpass, sans-serif;
#   font-size: clamp(2.2rem, 5vw, 4rem);
#   line-height: 1.08;
#   font-weight: 800;
#   letter-spacing: 0;
# }
# .ladybug-index .lede {
#   max-width: 44rem;
#   margin: 1rem 0 2rem;
#   color: var(--text);
#   font-size: 1.125rem;
# }
# .ladybug-index .grid {
#   display: grid;
#   grid-template-columns: repeat(auto-fit, minmax(min(100%, 20rem), 1fr));
#   gap: 1rem;
#   margin-top: 2rem;
# }
# .ladybug-index a.card {
#   display: grid;
#   grid-template-columns: auto 1fr;
#   gap: 1rem;
#   min-height: 10rem;
#   padding: 1rem;
#   color: var(--text);
#   text-decoration: none;
#   background: transparent;
#   border: 1px solid var(--border);
#   border-radius: .5rem;
#   box-shadow: var(--shadow);
#   transition: border-color .15s ease, background .15s ease;
# }
# .ladybug-index a.card:hover {
#   color: var(--text);
#   background: var(--panel);
#   border-color: #c1c3c8;
# }
# .ladybug-index .number {
#   width: 2rem;
#   height: 2rem;
#   border-radius: 999rem;
#   display: grid;
#   place-items: center;
#   color: var(--white);
#   background: var(--panel);
#   border: 1px solid var(--border);
#   font-size: .8125rem;
#   font-weight: 700;
# }
# .ladybug-index .title {
#   color: var(--white);
#   font-family: Nunito, Overpass, sans-serif;
#   font-size: 1.25rem;
#   line-height: 1.25;
#   font-weight: 700;
#   margin: .15rem 0 .4rem;
# }
# .ladybug-index .desc { color: var(--muted); font-size: .95rem; line-height: 1.55; }
# .ladybug-index .tag {
#   display: inline-block;
#   margin-top: .9rem;
#   color: var(--accent-high);
#   font-size: .8125rem;
#   font-weight: 700;
# }
# .ladybug-index code {
#   color: var(--white);
#   background: #353841;
#   border-radius: .25rem;
#   padding: .1rem .35rem;
#   font-family: 'SF Mono', SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#   font-size: .875em;
# }
# .ladybug-index .hint {
#   margin-top: 2rem;
#   padding: 1rem;
#   border: 1px solid var(--border);
#   border-left: .25rem solid var(--accent);
#   color: var(--text);
#   background: var(--panel);
# }
# </style>
#
# <div class="ladybug-index">
#   <div class="wrap">
#     <div class="brand"><span class="mark">L</span><span>Ladybug</span></div>
#     <h1>Ladybug + Icebug Notebook Index</h1>
#     <p class="lede">Notebooks are listed from simpler graph-query examples to more advanced storage and analytics workflows.</p>
#
#     <div class="grid">
#       <a class="card" href="ladybug-python-social-network.ipynb">
#         <span class="number">1</span>
#         <span><span class="title">Python Tutorial: Analyze a Social Network</span><span class="desc">Introductory Ladybug graph querying from Python.</span><span class="tag">Start here</span></span>
#       </a>
#       <a class="card" href="ladybug_duckdb_attached_starwars.ipynb">
#         <span class="number">2</span>
#         <span><span class="title">Star Wars Graph Stored in DuckDB</span><span class="desc">Attach a DuckDB database and declare a relationship table backed by an attached DuckDB table.</span><span class="tag">DuckDB attach</span></span>
#       </a>
#       <a class="card" href="ladybug_icebug_starwars.ipynb">
#         <span class="number">3</span>
#         <span><span class="title">Star Wars Graph Analytics</span><span class="desc">Query Arrow-backed data, persist it to native Ladybug storage, export CSR, and run Icebug analytics.</span><span class="tag">Arrow + native storage</span></span>
#       </a>
#       <a class="card" href="ladybug_icebug_memory_starwars.ipynb">
#         <span class="number">4</span>
#         <span><span class="title">Star Wars Analytics with Arrow CSR</span><span class="desc">Build Arrow CSR tables in memory and share them between Ladybug and Icebug.</span><span class="tag">In-memory CSR</span></span>
#       </a>
#       <a class="card" href="ladybug_icebug_disk_karate.ipynb">
#         <span class="number">5</span>
#         <span><span class="title">Karate Club from icebug-disk</span><span class="desc">Convert DuckDB tables to icebug-disk Parquet, load them natively in Ladybug, and run Icebug algorithms.</span><span class="tag">Disk workflow</span></span>
#       </a>
#     </div>
#
#     <div class="hint">Open this page with <code>uv run jupyter notebook index.ipynb</code>.</div>
#   </div>
# </div>
